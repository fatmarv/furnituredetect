# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.8/974.8 kB 31.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 108.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 86.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 37.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source='1.jpg' #output in detect/predict2
# Out:
# Ultralytics 8.3.108 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/1.jpg: 448x640 1 person, 1 dog, 210.4ms
# Speed: 10.9ms preprocess, 210.4ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=segment mode=predict model = yolov8n-seg.pt source='1.jpg' # output in segment/predict2
# Out:
# Ultralytics 8.3.108 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.20GHz)
# YOLOv8n-seg summary (fused): 85 layers, 3,404,320 parameters, 0 gradients, 12.6 GFLOPs
#
# image 1/1 /content/1.jpg: 448x640 1 person, 1 dog, 268.2ms
# Speed: 14.7ms preprocess, 268.2ms inference, 8.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/segment/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
#using python script
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
results = model.predict(source='1.jpg', save=True)  # Force saving the output

#cli command  !yolo task=detect mode=predict model=yolov8n.pt source='1.jpg'
# Out:
# image 1/1 /content/1.jpg: 448x640 1 person, 1 dog, 164.8ms
# Speed: 6.9ms preprocess, 164.8ms inference, 2.3ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/1.jpg: 448x640 1 person, 1 dog, 149.3ms
# Speed: 4.7ms preprocess, 149.3ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict

# %%
from IPython.display import Image

# Show the result image
Image(filename='runs/detect/predict/1.jpg')

# %%
modelseg = YOLO('yolov8n-seg.pt')
result = modelseg.predict(source='1.jpg', save=True)
# Out:
# ...
# 100%|██████████| 6.74M/6.74M [00:00<00:00, 56.5MB/s]
# image 1/1 /content/1.jpg: 448x640 1 person, 1 dog, 283.9ms
# Speed: 5.2ms preprocess, 283.9ms inference, 13.9ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/segment/predict

# %%
# Show the result image
Image(filename='runs/segment/predict/1.jpg')

# %%
## classification

# !yolo task = classify mode=predict model=yolov8n-cls.pt source ='1.jpg'
# Out:
# ...
# 100% 5.31M/5.31M [00:00<00:00, 46.4MB/s]
# Ultralytics 8.3.108 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.20GHz)
# YOLOv8n-cls summary (fused): 30 layers, 2,715,880 parameters, 0 gradients, 4.3 GFLOPs
#
# ...
# 100% 755k/755k [00:00<00:00, 10.2MB/s]
# image 1/1 /content/1.jpg: 224x224 vizsla 0.54, bloodhound 0.22, Rhodesian_ridgeback 0.18, redbone 0.01, Chesapeake_Bay_retriever 0.01, 35.9ms
# Speed: 39.8ms preprocess, 35.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
#view the result
Image(filename='runs/classify/predict/1.jpg')

# %% [markdown]
# ## Custom Model Funiture Detection

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
yaml_file = 'content/drive/furniture_dataset/data.yaml'
yaml_file
# Out:
# 'content/drive/furniture_dataset/data.yaml'

# %%
from ultralytics import YOLO

# modelfurniture = YOLO('yolov8n.pt') use pretrained model


# modelfurniture = YOLO('yolov8n.pt')  # or yolov8s.pt, etc.
modelfurniture = YOLO() #training  model from scratch
modelfurniture.train(data='/content/drive/MyDrive/furniture_dataset/data.yaml', epochs=50, imgsz=640)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 109MB/s]
# Ultralytics 8.3.108 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# after model is trained , validate the model

from ultralytics import YOLO

#using cli command to validate model
# !yolo task=detect mode=val model ='/content/runs/detect/train/weights/best.pt' data ='/content/drive/MyDrive/furniture_dataset/data.yaml')
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `)'
# /bin/bash: -c: line 1: `yolo task=detect mode=val model ='/content/runs/detect/train/weights/best.pt' data ='/content/drive/MyDrive/furniture_dataset/data.yaml')'

# %%
# testing model
#cli command

# !yolo task=detect mode=predict model='/content/runs/detect/train/weights/best.pt' conf=0.25 source ='/content/drive/MyDrive/furniture_dataset/test/images'
# Out:
# Ultralytics 8.3.108 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,583,712 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/140 /content/drive/MyDrive/furniture_dataset/test/images/1-Optima-single-bed_jpg.rf.18b3e43d1de7f80446d6c73fb7869296.jpg: 640x640 1 single-bed, 8.5ms
# image 2/140 /content/drive/MyDrive/furniture_dataset/test/images/1623369445-7C95WWliSVa10ed9uteI_jpg.rf.8aeb16c4152822d7a08db87a072c3388.jpg: 640x640 1 L-shaped-couch, 36.8ms
# image 3/140 /content/drive/MyDrive/furniture_dataset/test/images/1_jpg.rf.05f45ba420df8e02c447544b5bc5b753.jpg: 640x640 1 L-shaped-couch, 14.7ms
# image 4/140 /content/drive/MyDrive/furniture_dataset/test/images/20221124114251-1fe365b6-cb74-44de-8f8e-e55308dd1a64_jpg.rf.892f7bbcb830abf8003c4ba5443179e6.jpg: 640x640 1 tv-cabinet, 12.7ms
# ...
